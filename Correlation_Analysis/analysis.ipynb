# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Load the datasets
air_pollutants_path = '../NewData/Weekly_Air_Pollutants.csv'
climate_data_path = '../ClimateDataTeam/climate_data/merged_weekly_avg_temp.csv'
greenhouse_gas_path = '../NewData/Weekly_Greenhouse_Gas.csv'
population_path = '../NewData/Weekly_Population.csv'
power_usage_path = '../NewData/Weekly_Power_Usage.csv'

# %%
# Read the CSV files into DataFrames
print(os.getcwd())
air_pollutants_df = pd.read_csv(air_pollutants_path)
climate_data_df = pd.read_csv(climate_data_path)

# Convert datetime columns to pandas datetime format
air_pollutants_df['datetime'] = pd.to_datetime(air_pollutants_df['datetime'])
climate_data_df['datetime'] = pd.to_datetime(climate_data_df['datetime'])

# Merge datasets on datetime
merged_df = pd.merge(air_pollutants_df, climate_data_df, on='datetime', how='inner')
# Out:
# c:\Users\limul\Desktop\College\2_grade\2_semester\computational_statistics\teamProject\2024-2-CSP\Correlation_Analysis

# %%
# Compute the correlation matrix
correlation_matrix = merged_df.corr()

# Visualize the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix of Air Pollutants and Climate Data")
plt.show()

# %%
# Read the CSV files into DataFrames
greenhouse_gas_df = pd.read_csv(greenhouse_gas_path)
climate_data_df = pd.read_csv(climate_data_path)

# Convert datetime columns to pandas datetime format
greenhouse_gas_df['datetime'] = pd.to_datetime(greenhouse_gas_df['datetime'])
climate_data_df['datetime'] = pd.to_datetime(climate_data_df['datetime'])

# Merge datasets on datetime
merged_df = pd.merge(greenhouse_gas_df, climate_data_df, on='datetime', how='inner')

# %%
# Compute the correlation matrix
correlation_matrix = merged_df.corr()

# Visualize the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix of greenhouse_gas and Climate Data")
plt.show()

# %%
# Read the CSV files into DataFrames
population_df = pd.read_csv(population_path)
climate_data_df = pd.read_csv(climate_data_path)

# Convert datetime columns to pandas datetime format
population_df['datetime'] = pd.to_datetime(population_df['datetime'])
climate_data_df['datetime'] = pd.to_datetime(climate_data_df['datetime'])

# Merge datasets on datetime
merged_df = pd.merge(population_df, climate_data_df, on='datetime', how='inner')

# %%
# Compute the correlation matrix
correlation_matrix = merged_df.corr()

# Visualize the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix of population and Climate Data")
plt.show()

# %%
# Read the CSV files into DataFrames
power_usage_df = pd.read_csv(power_usage_path)
climate_data_df = pd.read_csv(climate_data_path)

# Convert datetime columns to pandas datetime format
power_usage_df['datetime'] = pd.to_datetime(power_usage_df['datetime'])
climate_data_df['datetime'] = pd.to_datetime(climate_data_df['datetime'])

# Merge datasets on datetime
merged_df = pd.merge(power_usage_df, climate_data_df, on='datetime', how='inner')

# %%
# Compute the correlation matrix
correlation_matrix = merged_df.corr()

# Visualize the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix of power_usage and Climate Data")
plt.show()
